# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
response_json = []
name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
long = []
max_temp = []
windspeed = []



# Make a request for each of the indices
for x in range(len(cities)):
    print(f"Processing Record: {x} of Set 1| {cities[x]}")

    # Get one of the posts
    response = requests.get(query_url + str(cities[x]))

    response_json.append(response.json())
    
    try:
     name_pull = response_json[x]['name']  
     cloudiness_pull = response_json[x]['clouds']['all']
     country_pull = response_json[x]['sys']['country']
     date_pull = response_json[x]['dt']
     humidity_pull = response_json[x]['main']['humidity']
     lat_pull = response_json[x]['coord']['lat']
     long_pull = response_json[x]['coord']['lon']
     maxtemp_pull = response_json[x]['main']['temp_max']
     wind_pull = response_json[x]['wind']['speed']

     name.append(name_pull)
     cloudiness.append(cloudiness_pull)
     country.append(country_pull)
     date.append(date_pull)
     humidity.append(humidity_pull)
     lat.append(lat_pull)
     long.append(long_pull)
     max_temp.append(maxtemp_pull) 
     windspeed.append(wind_pull)
    except:
     print("Datanot found")
    pass
# Out:
# Processing Record: 0 of Set 1| ushuaia
# Processing Record: 1 of Set 1| brwinow
# Processing Record: 2 of Set 1| amderma
# Datanot found
# Processing Record: 3 of Set 1| tsihombe
# Datanot found
# Processing Record: 4 of Set 1| hermanus
# Processing Record: 5 of Set 1| qaanaaq
# Processing Record: 6 of Set 1| hilo
# Processing Record: 7 of Set 1| kapaa
# Processing Record: 8 of Set 1| souillac
# Processing Record: 9 of Set 1| padang
# Processing Record: 10 of Set 1| arraial do cabo
# Processing Record: 11 of Set 1| bluff
# Processing Record: 12 of Set 1| avarua
# Processing Record: 13 of Set 1| wahran
# Datanot found
# Processing Record: 14 of Set 1| yellowknife
# Processing Record: 15 of Set 1| port hawkesbury
# Processing Record: 16 of Set 1| bahile
# Processing Record: 17 of Set 1| atuona
# Processing Record: 18 of Set 1| barcelos
# Processing Record: 19 of Set 1| belushya guba
# Datanot found
# Processing Record: 20 of Set 1| rikitea
# ...

# %%
from pprint import pprint

pprint(response.json())
# Out:
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 36.3, 'lon': 139.8},
#  'dt': 1584558470,
#  'id': 1853483,
#  'main': {'feels_like': 44.67,
#           'humidity': 86,
#           'pressure': 1013,
#           'temp': 47.97,
#           'temp_max': 53.01,
#           'temp_min': 41},
#  'name': 'Oyama',
#  'sys': {'country': 'JP',
#          'id': 7957,
#          'sunrise': 1584564360,
#          'sunset': 1584607869,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 20, 'speed': 3.36}}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "Name" : name,
    "Cloudiness (%)" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity (%)" : humidity,
    "Lat" : lat,
    "Long" : long,
    "Max Temp (Fahrenheit)" : max_temp,
    "Wind Speed (mph)" : windspeed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.to_csv("weather_data.csv", encoding="utf-8", index=False)
weather_data.head(30)
# Out:
#                Name  Cloudiness (%) Country        Date  Humidity (%)    Lat  \
# 0           Ushuaia              90      AR  1584558380            81 -54.80
# 1     Gmina Brwinów              71      PL  1584558380            57  52.14
# 2          Hermanus               0      ZA  1584558381            92 -34.42
# 3           Qaanaaq               3      GL  1584558381            63  77.48
# 4              Hilo              75      US  1584558317            83  19.73
# 5             Kapaa              90      US  1584558381            94  22.08
# 6          Souillac              75      MU  1584558381            83 -20.52
# 7            Padang             100      ID  1584558381            98  -0.95
# 8   Arraial do Cabo              20      BR  1584558381            78 -22.97
# 9             Bluff              75      NZ  1584558382            65 -46.60
# 10           Avarua              72      CK  1584558382            83 -21.21
# ...

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Latitude vs. Temperature Plot
plt.scatter(lat, max_temp, marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperatures")
plt.ylabel("Temperature (Fahrenheit)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Temperature_Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Latitude vs. Humidity Plot
plt.scatter(lat, humidity, marker="x")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Humidity_Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Latitude vs. Temperature Plot
plt.scatter(lat, cloudiness, marker="*")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness %")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Cloudiness_Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Latitude vs. Wind Speed Plot
plt.scatter(lat, windspeed, marker="d")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (mph)")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Wind_Speed_Plot.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

weather_data_northern = weather_data[(weather_data['Lat'] > 0)]
weather_data_northern_df = pd.DataFrame(weather_data_northern)
weather_data_northern_df
# Out:
#               Name  Cloudiness (%) Country        Date  Humidity (%)    Lat  \
# 1    Gmina Brwinów              71      PL  1584558380            57  52.14
# 3          Qaanaaq               3      GL  1584558381            63  77.48
# 4             Hilo              75      US  1584558317            83  19.73
# 5            Kapaa              90      US  1584558381            94  22.08
# 11     Yellowknife               5      CA  1584558283            64  62.46
# ..             ...             ...     ...         ...           ...    ...
# 554      Lumberton              75      US  1584558468            60  34.62
# 557       Djibouti              54      DJ  1584558184            79  11.50
# 558        Sarkand              42      KZ  1584558469            83  45.41
# 559       Jinchang              16      CN  1584558469            26  38.50
# 562          Oyama              20      JP  1584558470            86  36.30
#
#        Long  Max Temp (Fahrenheit)  Wind Speed (mph)
# ...

# %%
weather_data_southern = weather_data[(weather_data['Lat'] < 0)]
weather_data_southern_df = pd.DataFrame(weather_data_southern)
weather_data_southern_df
# Out:
#                 Name  Cloudiness (%) Country        Date  Humidity (%)    Lat  \
# 0            Ushuaia              90      AR  1584558380            81 -54.80
# 2           Hermanus               0      ZA  1584558381            92 -34.42
# 6           Souillac              75      MU  1584558381            83 -20.52
# 7             Padang             100      ID  1584558381            98  -0.95
# 8    Arraial do Cabo              20      BR  1584558381            78 -22.97
# ..               ...             ...     ...         ...           ...    ...
# 550        Tuatapere              38      NZ  1584558468            65 -46.13
# 555      Grand Gaube              75      MU  1584558469            83 -20.01
# 556        Concordia              75      AR  1584558469            78 -31.39
# 560          Dunedin              93      NZ  1584558251            75 -45.87
# 561           Camaná              35      PE  1584558470            59 -16.62
#
# ...

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
n_latitude = weather_data_northern_df['Lat']
n_temp = weather_data_northern_df['Max Temp (Fahrenheit)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_latitude, n_temp)
regress_values = n_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(n_latitude,n_temp)

#plot regression line with formula
plt.plot(n_latitude,regress_values,"r-")
plt.annotate(line_eq,(2,2),fontsize=15,color="red")

#Labels and titles
plt.title("Northern City Latitude vs. Maximum Temperature")
plt.xlabel('Latitude')
plt.ylabel('Temperature (Fahrenheit)')
plt.xlim(0,90)
plt.ylim(-30,130)

print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Northern_Latitude_vs_Temperature_Plot.png")
plt.show()
# Out:
# The r-squared is: -0.8920363153710197

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
s_latitude = weather_data_southern_df['Lat']
s_temp = weather_data_southern_df['Max Temp (Fahrenheit)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_latitude, s_temp)
s_regress_values = s_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(s_latitude,s_temp)

#plot regression line with formula
plt.plot(s_latitude,s_regress_values,"r-")
plt.annotate(line_eq,(-80,0),fontsize=15,color="red")

#Labels and titles
plt.title("Southern City Latitude vs. Maximum Temperature")
plt.xlabel('Latitude')
plt.ylabel('Temperature (Fahrenheit)')
plt.xlim(-90,0)
plt.ylim(-30,130)
print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Southern_Latitude_vs_Temperature_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.6181311124785408

# %%
'''Maximum Temperature data does show consistency as the city moves further from the Equator the temperature tends to decrease'''
# Out:
# 'Maximum Temperature data does show consistency as the city moves further from the Equator the temperature tends to decrease'

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
n_latitude = weather_data_northern_df['Lat']
n_humidity = weather_data_northern_df['Humidity (%)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_latitude, n_humidity)
regress_values = n_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(n_latitude,n_humidity)

#plot regression line with formula
plt.plot(n_latitude,regress_values,"r-")
plt.annotate(line_eq,(50,10),fontsize=15,color="red")

#Labels and titles
plt.title("Northern City Latitude vs. Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.xlim(0,90)
plt.ylim(0,110)

print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Northern_Latitude_vs_Humidity_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.3504106348000642

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
s_latitude = weather_data_southern_df['Lat']
s_humidity = weather_data_southern_df['Humidity (%)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_latitude, s_humidity)
s_regress_values = s_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(s_latitude,s_humidity)

#plot regression line with formula
plt.plot(s_latitude,s_regress_values,"r-")
plt.annotate(line_eq,(-80,20),fontsize=15,color="red")

#Labels and titles
plt.title("Southern City Latitude vs. Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.xlim(-90,0)
plt.ylim(0,110)
print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Southern_Latitude_vs_Humidity_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.28660116498892485

# %%
'''There seems to be little to no correlation between the humidity and latitude'''

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
n_latitude = weather_data_northern_df['Lat']
n_cloudiness = weather_data_northern_df['Cloudiness (%)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_latitude, n_cloudiness)
regress_values = n_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(n_latitude,n_cloudiness)

#plot regression line with formula
plt.plot(n_latitude,regress_values,"r-")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")

#Labels and titles
plt.title("Northern City Latitude vs. Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.xlim(0,90)
plt.ylim(-30,110)

print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Northern_Latitude_vs_Cloudiness_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.2506816354526845

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
s_latitude = weather_data_southern_df['Lat']
s_cloudiness = weather_data_southern_df['Cloudiness (%)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_latitude, s_cloudiness)
s_regress_values = s_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(s_latitude,s_cloudiness)

#plot regression line with formula
plt.plot(s_latitude,s_regress_values,"r-")
plt.annotate(line_eq,(-80,10),fontsize=15,color="red")

#Labels and titles
plt.title("Southern City Latitude vs. Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.xlim(-90,0)
plt.ylim(-10,110)
print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Southern_Latitude_vs_Cloudiness_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.2744933259554826

# %%
'''There seems to be little to no correlation between cloudiness and latitude'''

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
n_latitude = weather_data_northern_df['Lat']
n_windspeed = weather_data_northern_df['Wind Speed (mph)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_latitude, n_windspeed)
regress_values = n_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(n_latitude,n_windspeed)

#plot regression line with formula
plt.plot(n_latitude,regress_values,"r-")
plt.annotate(line_eq,(10,40),fontsize=15,color="red")

#Labels and titles
plt.title("Northern City Latitude vs. Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.xlim(0,90)
plt.ylim(-10,50)

print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Northern_Latitude_vs_Wind_Speed_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.12401303654826844

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
s_latitude = weather_data_southern_df['Lat']
s_windspeed = weather_data_southern_df['Wind Speed (mph)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_latitude, s_windspeed)
s_regress_values = s_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(s_latitude,s_windspeed)

#plot regression line with formula
plt.plot(s_latitude,s_regress_values,"r-")
plt.annotate(line_eq,(-40,40),fontsize=15,color="red")

#Labels and titles
plt.title("Southern City Latitude vs. Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.xlim(-90,0)
plt.ylim(-10,50)
print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Southern_Latitude_vs_Wind_Speed_Plot.png")
plt.show()
# Out:
# The r-squared is: -0.3629652780605263

# %%
'''There seems to be slightly lower windspeed at the equator but the data is poorly correlated'''
