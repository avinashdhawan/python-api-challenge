# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 590

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
response_json = []
name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
long = []
max_temp = []
windspeed = []



# Make a request for each of the indices
for x in range(len(cities)):
    print(f"Processing Record: {x} of Set 1| {cities[x]}")

    # Get one of the posts
    response = requests.get(query_url + str(cities[x]))

    response_json.append(response.json())
    
    try:
     name_pull = response_json[x]['name']  
     cloudiness_pull = response_json[x]['clouds']['all']
     country_pull = response_json[x]['sys']['country']
     date_pull = response_json[x]['dt']
     humidity_pull = response_json[x]['main']['humidity']
     lat_pull = response_json[x]['coord']['lat']
     long_pull = response_json[x]['coord']['lon']
     maxtemp_pull = response_json[x]['main']['temp_max']
     wind_pull = response_json[x]['wind']['speed']

     name.append(name_pull)
     cloudiness.append(cloudiness_pull)
     country.append(country_pull)
     date.append(date_pull)
     humidity.append(humidity_pull)
     lat.append(lat_pull)
     long.append(long_pull)
     max_temp.append(maxtemp_pull) 
     windspeed.append(wind_pull)
    except:
     print("Datanot found")
    pass
# Out:
# Processing Record: 0 of Set 1| santa cruz
# Processing Record: 1 of Set 1| sfantu gheorghe
# Processing Record: 2 of Set 1| richards bay
# Processing Record: 3 of Set 1| kavieng
# Processing Record: 4 of Set 1| tabuk
# Processing Record: 5 of Set 1| ushuaia
# Processing Record: 6 of Set 1| paracuru
# Processing Record: 7 of Set 1| punta arenas
# Processing Record: 8 of Set 1| kovdor
# Processing Record: 9 of Set 1| miri
# Processing Record: 10 of Set 1| hovd
# Processing Record: 11 of Set 1| mys shmidta
# Datanot found
# Processing Record: 12 of Set 1| jamestown
# Processing Record: 13 of Set 1| kudahuvadhoo
# Processing Record: 14 of Set 1| avarua
# Processing Record: 15 of Set 1| clyde river
# Processing Record: 16 of Set 1| quang ngai
# Processing Record: 17 of Set 1| albany
# Processing Record: 18 of Set 1| port lincoln
# Processing Record: 19 of Set 1| dinar
# Processing Record: 20 of Set 1| atuona
# Processing Record: 21 of Set 1| mar del plata
# Processing Record: 22 of Set 1| sao joao da barra
# Processing Record: 23 of Set 1| pisco
# Processing Record: 24 of Set 1| sobolevo
# Processing Record: 25 of Set 1| labuhan
# Processing Record: 26 of Set 1| tuatapere
# Processing Record: 27 of Set 1| lebu
# Processing Record: 28 of Set 1| torbay
# Processing Record: 29 of Set 1| marsa matruh
# Processing Record: 30 of Set 1| kaitangata
# Processing Record: 31 of Set 1| tasiilaq
# Processing Record: 32 of Set 1| bethel
# Processing Record: 33 of Set 1| illoqqortoormiut
# Datanot found
# Processing Record: 34 of Set 1| chuy
# Processing Record: 35 of Set 1| taolanaro
# Datanot found
# Processing Record: 36 of Set 1| castro
# Processing Record: 37 of Set 1| rikitea
# Processing Record: 38 of Set 1| hobart
# Processing Record: 39 of Set 1| ostrovnoy
# Processing Record: 40 of Set 1| pangody
# Processing Record: 41 of Set 1| ambodifototra
# Datanot found
# Processing Record: 42 of Set 1| wulanhaote
# Datanot found
# Processing Record: 43 of Set 1| guapore
# Processing Record: 44 of Set 1| siwana
# Processing Record: 45 of Set 1| hithadhoo
# Processing Record: 46 of Set 1| shimoda
# Processing Record: 47 of Set 1| sorvag
# Datanot found
# Processing Record: 48 of Set 1| san juan de los morros
# Processing Record: 49 of Set 1| avera
# Processing Record: 50 of Set 1| port alfred
# Processing Record: 51 of Set 1| harrisburg
# Processing Record: 52 of Set 1| vaini
# Processing Record: 53 of Set 1| namibe
# Processing Record: 54 of Set 1| luderitz
# Processing Record: 55 of Set 1| hasaki
# Processing Record: 56 of Set 1| northam
# Processing Record: 57 of Set 1| mataura
# Processing Record: 58 of Set 1| belushya guba
# Datanot found
# Processing Record: 59 of Set 1| khandbari
# Processing Record: 60 of Set 1| arica
# Processing Record: 61 of Set 1| barstow
# Processing Record: 62 of Set 1| khuzhir
# Processing Record: 63 of Set 1| blackwater
# Processing Record: 64 of Set 1| talnakh
# Processing Record: 65 of Set 1| butaritari
# Processing Record: 66 of Set 1| kastamonu
# Processing Record: 67 of Set 1| piltene
# Processing Record: 68 of Set 1| arraial do cabo
# Processing Record: 69 of Set 1| lima
# Processing Record: 70 of Set 1| bengkulu
# Processing Record: 71 of Set 1| vardo
# Processing Record: 72 of Set 1| kapaa
# Processing Record: 73 of Set 1| cape town
# Processing Record: 74 of Set 1| new norfolk
# Processing Record: 75 of Set 1| burica
# Datanot found
# Processing Record: 76 of Set 1| hermanus
# Processing Record: 77 of Set 1| duz
# Datanot found
# Processing Record: 78 of Set 1| geraldton
# Processing Record: 79 of Set 1| ponta do sol
# Processing Record: 80 of Set 1| lagoa
# Processing Record: 81 of Set 1| mount gambier
# Processing Record: 82 of Set 1| dikson
# Processing Record: 83 of Set 1| khani
# Processing Record: 84 of Set 1| bluff
# Processing Record: 85 of Set 1| barrow
# Processing Record: 86 of Set 1| fort nelson
# Processing Record: 87 of Set 1| los llanos de aridane
# Processing Record: 88 of Set 1| yellowknife
# Processing Record: 89 of Set 1| barentsburg
# Datanot found
# Processing Record: 90 of Set 1| kralendijk
# Processing Record: 91 of Set 1| dingle
# Processing Record: 92 of Set 1| sisimiut
# Processing Record: 93 of Set 1| bonavista
# Processing Record: 94 of Set 1| bambous virieux
# Processing Record: 95 of Set 1| abomsa
# Processing Record: 96 of Set 1| grand-lahou
# Processing Record: 97 of Set 1| kanniyakumari
# Processing Record: 98 of Set 1| lagunas
# Processing Record: 99 of Set 1| komsomolskiy
# Processing Record: 100 of Set 1| bilyayivka
# Processing Record: 101 of Set 1| saint-philippe
# Processing Record: 102 of Set 1| kodiak
# Processing Record: 103 of Set 1| saint-pierre
# Processing Record: 104 of Set 1| carnarvon
# Processing Record: 105 of Set 1| pella
# Processing Record: 106 of Set 1| sao filipe
# Processing Record: 107 of Set 1| boyabat
# Processing Record: 108 of Set 1| horasan
# Processing Record: 109 of Set 1| saint-augustin
# Processing Record: 110 of Set 1| iqaluit
# Processing Record: 111 of Set 1| srednekolymsk
# Processing Record: 112 of Set 1| khovu-aksy
# Processing Record: 113 of Set 1| fare
# Processing Record: 114 of Set 1| bud
# Processing Record: 115 of Set 1| salina
# Processing Record: 116 of Set 1| kamenka
# Processing Record: 117 of Set 1| cap malheureux
# Processing Record: 118 of Set 1| ust-maya
# Processing Record: 119 of Set 1| luneville
# Processing Record: 120 of Set 1| nalut
# Processing Record: 121 of Set 1| makkaveyevo
# Processing Record: 122 of Set 1| sinnamary
# Processing Record: 123 of Set 1| pevek
# Processing Record: 124 of Set 1| mayo
# Processing Record: 125 of Set 1| ancud
# Processing Record: 126 of Set 1| lavrentiya
# Processing Record: 127 of Set 1| cidreira
# Processing Record: 128 of Set 1| husavik
# Processing Record: 129 of Set 1| thiruvananthapuram
# Processing Record: 130 of Set 1| longyearbyen
# Processing Record: 131 of Set 1| busselton
# Processing Record: 132 of Set 1| honningsvag
# Processing Record: 133 of Set 1| cabanas
# Processing Record: 134 of Set 1| mount isa
# Processing Record: 135 of Set 1| tankara
# Processing Record: 136 of Set 1| andros
# Processing Record: 137 of Set 1| tsihombe
# Datanot found
# Processing Record: 138 of Set 1| orsha
# Processing Record: 139 of Set 1| makakilo city
# Processing Record: 140 of Set 1| saskylakh
# Processing Record: 141 of Set 1| cockburn town
# Processing Record: 142 of Set 1| nikolskoye
# Processing Record: 143 of Set 1| terrace bay
# Processing Record: 144 of Set 1| necochea
# Processing Record: 145 of Set 1| sabang
# Processing Record: 146 of Set 1| manaquiri
# Processing Record: 147 of Set 1| tibati
# Processing Record: 148 of Set 1| urucui
# Processing Record: 149 of Set 1| yaring
# Processing Record: 150 of Set 1| zhaotong
# Processing Record: 151 of Set 1| bata
# Processing Record: 152 of Set 1| rungata
# Datanot found
# Processing Record: 153 of Set 1| vila franca do campo
# Processing Record: 154 of Set 1| asfi
# Processing Record: 155 of Set 1| ishigaki
# Processing Record: 156 of Set 1| ales
# Processing Record: 157 of Set 1| coromandel
# Processing Record: 158 of Set 1| san patricio
# Processing Record: 159 of Set 1| leninskoye
# Processing Record: 160 of Set 1| hilo
# Processing Record: 161 of Set 1| dunedin
# Processing Record: 162 of Set 1| barawe
# Datanot found
# Processing Record: 163 of Set 1| coquimbo
# Processing Record: 164 of Set 1| ambon
# Processing Record: 165 of Set 1| port-gentil
# Processing Record: 166 of Set 1| qaanaaq
# Processing Record: 167 of Set 1| broken hill
# Processing Record: 168 of Set 1| east london
# Processing Record: 169 of Set 1| saint george
# Processing Record: 170 of Set 1| cherskiy
# Processing Record: 171 of Set 1| halifax
# Processing Record: 172 of Set 1| biltine
# Processing Record: 173 of Set 1| kazalinsk
# Datanot found
# Processing Record: 174 of Set 1| bredasdorp
# Processing Record: 175 of Set 1| luzhou
# Processing Record: 176 of Set 1| soyo
# Processing Record: 177 of Set 1| portland
# Processing Record: 178 of Set 1| samusu
# Datanot found
# Processing Record: 179 of Set 1| thompson
# Processing Record: 180 of Set 1| rolim de moura
# Datanot found
# Processing Record: 181 of Set 1| half moon bay
# Processing Record: 182 of Set 1| porto novo
# Processing Record: 183 of Set 1| aligudarz
# Processing Record: 184 of Set 1| qaqortoq
# Processing Record: 185 of Set 1| salta
# Processing Record: 186 of Set 1| laramie
# Processing Record: 187 of Set 1| puerto ayora
# Processing Record: 188 of Set 1| cascavel
# Processing Record: 189 of Set 1| leningradskiy
# Processing Record: 190 of Set 1| aiken
# Processing Record: 191 of Set 1| laguna
# Processing Record: 192 of Set 1| manggar
# Processing Record: 193 of Set 1| lerwick
# Processing Record: 194 of Set 1| poronaysk
# Processing Record: 195 of Set 1| college
# Processing Record: 196 of Set 1| vaitupu
# Datanot found
# Processing Record: 197 of Set 1| awjilah
# Processing Record: 198 of Set 1| bayeux
# Processing Record: 199 of Set 1| kudat
# Processing Record: 200 of Set 1| touros
# Processing Record: 201 of Set 1| ilulissat
# Processing Record: 202 of Set 1| bartlesville
# Processing Record: 203 of Set 1| guerrero negro
# Processing Record: 204 of Set 1| salalah
# Processing Record: 205 of Set 1| lorengau
# Processing Record: 206 of Set 1| moyale
# Processing Record: 207 of Set 1| hualmay
# Processing Record: 208 of Set 1| port elizabeth
# Processing Record: 209 of Set 1| mopipi
# Processing Record: 210 of Set 1| lamu
# Processing Record: 211 of Set 1| kieta
# Processing Record: 212 of Set 1| syracuse
# Processing Record: 213 of Set 1| skalistyy
# Datanot found
# Processing Record: 214 of Set 1| villa bruzual
# Processing Record: 215 of Set 1| izmalkovo
# Processing Record: 216 of Set 1| coahuayana
# Processing Record: 217 of Set 1| monticello
# Processing Record: 218 of Set 1| yulara
# Processing Record: 219 of Set 1| suzu
# Datanot found
# Processing Record: 220 of Set 1| watsa
# Processing Record: 221 of Set 1| hervey bay
# Processing Record: 222 of Set 1| maningrida
# Processing Record: 223 of Set 1| goderich
# Processing Record: 224 of Set 1| saldanha
# Processing Record: 225 of Set 1| novoagansk
# Processing Record: 226 of Set 1| severo-kurilsk
# Processing Record: 227 of Set 1| ribeira grande
# Processing Record: 228 of Set 1| aklavik
# Processing Record: 229 of Set 1| haines junction
# Processing Record: 230 of Set 1| waddan
# Processing Record: 231 of Set 1| altamira
# Processing Record: 232 of Set 1| sangmelima
# Processing Record: 233 of Set 1| saint-francois
# Processing Record: 234 of Set 1| labutta
# Datanot found
# Processing Record: 235 of Set 1| nelson bay
# Processing Record: 236 of Set 1| preobrazheniye
# Processing Record: 237 of Set 1| wladyslawowo
# Processing Record: 238 of Set 1| jacareacanga
# Processing Record: 239 of Set 1| chicama
# Processing Record: 240 of Set 1| couva
# Processing Record: 241 of Set 1| port hedland
# Processing Record: 242 of Set 1| puerto escondido
# Processing Record: 243 of Set 1| vanimo
# Processing Record: 244 of Set 1| koplik
# Processing Record: 245 of Set 1| bowen
# Processing Record: 246 of Set 1| riyadh
# Processing Record: 247 of Set 1| khatanga
# Processing Record: 248 of Set 1| ranavav
# Processing Record: 249 of Set 1| katsuura
# Processing Record: 250 of Set 1| tiksi
# Processing Record: 251 of Set 1| gatton
# Processing Record: 252 of Set 1| faanui
# Processing Record: 253 of Set 1| suntar
# Processing Record: 254 of Set 1| grand river south east
# Datanot found
# Processing Record: 255 of Set 1| tsienyane
# Datanot found
# Processing Record: 256 of Set 1| tuktoyaktuk
# Processing Record: 257 of Set 1| sorland
# Processing Record: 258 of Set 1| taltal
# Processing Record: 259 of Set 1| upernavik
# Processing Record: 260 of Set 1| west odessa
# Processing Record: 261 of Set 1| namwala
# Processing Record: 262 of Set 1| pangai
# Processing Record: 263 of Set 1| isangel
# Processing Record: 264 of Set 1| shar
# Processing Record: 265 of Set 1| xai-xai
# Processing Record: 266 of Set 1| acarau
# Processing Record: 267 of Set 1| satwas
# Processing Record: 268 of Set 1| olafsvik
# Processing Record: 269 of Set 1| tuggurt
# Datanot found
# Processing Record: 270 of Set 1| airai
# Processing Record: 271 of Set 1| constitucion
# Processing Record: 272 of Set 1| santa barbara
# Processing Record: 273 of Set 1| myitkyina
# Processing Record: 274 of Set 1| hay river
# Processing Record: 275 of Set 1| coihaique
# Processing Record: 276 of Set 1| yar-sale
# Processing Record: 277 of Set 1| sinkat
# Datanot found
# Processing Record: 278 of Set 1| adrar
# Processing Record: 279 of Set 1| shirokiy
# Processing Record: 280 of Set 1| georgetown
# Processing Record: 281 of Set 1| fortuna
# Processing Record: 282 of Set 1| evensk
# Processing Record: 283 of Set 1| pathein
# Processing Record: 284 of Set 1| nizhneyansk
# Datanot found
# Processing Record: 285 of Set 1| caraballeda
# Processing Record: 286 of Set 1| gat
# Processing Record: 287 of Set 1| baker city
# Processing Record: 288 of Set 1| saleaula
# Datanot found
# Processing Record: 289 of Set 1| baruun-urt
# Processing Record: 290 of Set 1| ulaanbaatar
# Processing Record: 291 of Set 1| seoul
# Processing Record: 292 of Set 1| rock sound
# Processing Record: 293 of Set 1| mabaruma
# Processing Record: 294 of Set 1| milazzo
# Processing Record: 295 of Set 1| berlevag
# Processing Record: 296 of Set 1| silver city
# Processing Record: 297 of Set 1| ponta delgada
# Processing Record: 298 of Set 1| itarema
# Processing Record: 299 of Set 1| honiara
# Processing Record: 300 of Set 1| toccoa
# Processing Record: 301 of Set 1| mpophomeni
# Processing Record: 302 of Set 1| marzuq
# Processing Record: 303 of Set 1| roald
# Processing Record: 304 of Set 1| jablah
# Processing Record: 305 of Set 1| provideniya
# Processing Record: 306 of Set 1| kununurra
# Processing Record: 307 of Set 1| mahebourg
# Processing Record: 308 of Set 1| zhezkazgan
# Processing Record: 309 of Set 1| codrington
# Processing Record: 310 of Set 1| svetlyy
# Processing Record: 311 of Set 1| olden
# Processing Record: 312 of Set 1| nantucket
# Processing Record: 313 of Set 1| ugoofaaru
# Processing Record: 314 of Set 1| komsomolets
# Processing Record: 315 of Set 1| hamilton
# Processing Record: 316 of Set 1| gamba
# Processing Record: 317 of Set 1| repcelak
# Processing Record: 318 of Set 1| bonthe
# Processing Record: 319 of Set 1| seymchan
# Processing Record: 320 of Set 1| millau
# Processing Record: 321 of Set 1| srikakulam
# Processing Record: 322 of Set 1| wuda
# Processing Record: 323 of Set 1| talara
# Processing Record: 324 of Set 1| ahipara
# Processing Record: 325 of Set 1| mahibadhoo
# Processing Record: 326 of Set 1| umea
# Processing Record: 327 of Set 1| borogontsy
# Processing Record: 328 of Set 1| magomeni
# Processing Record: 329 of Set 1| kawalu
# Processing Record: 330 of Set 1| malmesbury
# Processing Record: 331 of Set 1| tsumeb
# Processing Record: 332 of Set 1| cabo san lucas
# Processing Record: 333 of Set 1| kulunda
# Processing Record: 334 of Set 1| tocopilla
# Processing Record: 335 of Set 1| vestmanna
# Processing Record: 336 of Set 1| jatai
# Processing Record: 337 of Set 1| solnechnyy
# Processing Record: 338 of Set 1| sorong
# Processing Record: 339 of Set 1| asau
# Processing Record: 340 of Set 1| tumannyy
# Datanot found
# Processing Record: 341 of Set 1| mlonggo
# Processing Record: 342 of Set 1| telemaco borba
# Processing Record: 343 of Set 1| hohhot
# Processing Record: 344 of Set 1| najran
# Processing Record: 345 of Set 1| tabiauea
# Datanot found
# Processing Record: 346 of Set 1| ozerne
# Processing Record: 347 of Set 1| opuwo
# Processing Record: 348 of Set 1| rio grande
# Processing Record: 349 of Set 1| dumas
# Processing Record: 350 of Set 1| florianopolis
# Processing Record: 351 of Set 1| bridgetown
# Processing Record: 352 of Set 1| mogadishu
# Processing Record: 353 of Set 1| stephenville
# Processing Record: 354 of Set 1| banda aceh
# Processing Record: 355 of Set 1| puerto madero
# Processing Record: 356 of Set 1| chornobay
# Processing Record: 357 of Set 1| san ignacio
# Processing Record: 358 of Set 1| dogondoutchi
# Processing Record: 359 of Set 1| muzaffargarh
# Processing Record: 360 of Set 1| sao cristovao
# Processing Record: 361 of Set 1| dubovka
# Processing Record: 362 of Set 1| dongning
# Processing Record: 363 of Set 1| raudeberg
# Processing Record: 364 of Set 1| weimar
# Processing Record: 365 of Set 1| north bay
# Processing Record: 366 of Set 1| westport
# Processing Record: 367 of Set 1| broome
# Processing Record: 368 of Set 1| maine-soroa
# Processing Record: 369 of Set 1| nanortalik
# Processing Record: 370 of Set 1| hambantota
# Processing Record: 371 of Set 1| henties bay
# Processing Record: 372 of Set 1| blagoyevo
# Processing Record: 373 of Set 1| alekseyevsk
# Processing Record: 374 of Set 1| odweyne
# Processing Record: 375 of Set 1| lolua
# Datanot found
# Processing Record: 376 of Set 1| mackay
# Processing Record: 377 of Set 1| north bend
# Processing Record: 378 of Set 1| maniitsoq
# Processing Record: 379 of Set 1| puerto penasco
# Processing Record: 380 of Set 1| dalbandin
# Processing Record: 381 of Set 1| key west
# Processing Record: 382 of Set 1| del rio
# Processing Record: 383 of Set 1| antofagasta
# Processing Record: 384 of Set 1| vitim
# Processing Record: 385 of Set 1| almaznyy
# Processing Record: 386 of Set 1| port blair
# Processing Record: 387 of Set 1| oum hadjer
# Processing Record: 388 of Set 1| saint john
# Processing Record: 389 of Set 1| victoria
# Processing Record: 390 of Set 1| cangzhou
# Processing Record: 391 of Set 1| bintulu
# Processing Record: 392 of Set 1| angoram
# Processing Record: 393 of Set 1| wilmington island
# Processing Record: 394 of Set 1| saryshagan
# Datanot found
# Processing Record: 395 of Set 1| samarai
# Processing Record: 396 of Set 1| guane
# Processing Record: 397 of Set 1| shingu
# Processing Record: 398 of Set 1| mitu
# Processing Record: 399 of Set 1| sandusky
# Processing Record: 400 of Set 1| zhigansk
# Processing Record: 401 of Set 1| torbat-e jam
# Processing Record: 402 of Set 1| corn island
# Processing Record: 403 of Set 1| petropavlovsk-kamchatskiy
# Processing Record: 404 of Set 1| rosarito
# Processing Record: 405 of Set 1| kualakapuas
# Processing Record: 406 of Set 1| new london
# Processing Record: 407 of Set 1| santa vitoria do palmar
# Processing Record: 408 of Set 1| hit
# Processing Record: 409 of Set 1| harwich
# Processing Record: 410 of Set 1| kavaratti
# Processing Record: 411 of Set 1| tura
# Processing Record: 412 of Set 1| prokopyevsk
# Processing Record: 413 of Set 1| port macquarie
# Processing Record: 414 of Set 1| fairbanks
# Processing Record: 415 of Set 1| coolum beach
# Processing Record: 416 of Set 1| tecoanapa
# Processing Record: 417 of Set 1| makung
# Datanot found
# Processing Record: 418 of Set 1| lensk
# Processing Record: 419 of Set 1| stoyba
# Datanot found
# Processing Record: 420 of Set 1| kibondo
# Processing Record: 421 of Set 1| esperance
# Processing Record: 422 of Set 1| moengo
# Processing Record: 423 of Set 1| tabas
# Processing Record: 424 of Set 1| sentyabrskiy
# Datanot found
# Processing Record: 425 of Set 1| norman wells
# Processing Record: 426 of Set 1| madang
# Processing Record: 427 of Set 1| griffith
# Processing Record: 428 of Set 1| ukiah
# Processing Record: 429 of Set 1| omboue
# Processing Record: 430 of Set 1| fayetteville
# Processing Record: 431 of Set 1| sur
# Processing Record: 432 of Set 1| puerto del rosario
# Processing Record: 433 of Set 1| astoria
# Processing Record: 434 of Set 1| buchanan
# Processing Record: 435 of Set 1| cumra
# Processing Record: 436 of Set 1| karamea
# Datanot found
# Processing Record: 437 of Set 1| ati
# Processing Record: 438 of Set 1| paramonga
# Processing Record: 439 of Set 1| te anau
# Processing Record: 440 of Set 1| namatanai
# Processing Record: 441 of Set 1| soller
# Processing Record: 442 of Set 1| cayenne
# Processing Record: 443 of Set 1| msowero
# Processing Record: 444 of Set 1| aflu
# Datanot found
# Processing Record: 445 of Set 1| solhan
# Processing Record: 446 of Set 1| aykhal
# Processing Record: 447 of Set 1| calbuco
# Processing Record: 448 of Set 1| marawi
# Processing Record: 449 of Set 1| vostok
# Processing Record: 450 of Set 1| palabuhanratu
# Datanot found
# Processing Record: 451 of Set 1| cabo rojo
# Processing Record: 452 of Set 1| barra do bugres
# Processing Record: 453 of Set 1| cairns
# Processing Record: 454 of Set 1| kirakira
# Processing Record: 455 of Set 1| turukhansk
# Processing Record: 456 of Set 1| chimore
# Processing Record: 457 of Set 1| vyshestebliyevskaya
# Processing Record: 458 of Set 1| rumoi
# Processing Record: 459 of Set 1| lompoc
# Processing Record: 460 of Set 1| sioux lookout
# Processing Record: 461 of Set 1| sao joao de pirabas
# Processing Record: 462 of Set 1| launceston
# Processing Record: 463 of Set 1| gandhinagar
# Processing Record: 464 of Set 1| ankpa
# Processing Record: 465 of Set 1| kuito
# Processing Record: 466 of Set 1| nuuk
# Processing Record: 467 of Set 1| rawah
# Processing Record: 468 of Set 1| meiganga
# Processing Record: 469 of Set 1| zeya
# Processing Record: 470 of Set 1| podsineye
# Processing Record: 471 of Set 1| abbeville
# Processing Record: 472 of Set 1| letlhakane
# Processing Record: 473 of Set 1| arlit
# Processing Record: 474 of Set 1| bodden town
# Processing Record: 475 of Set 1| bafq
# Processing Record: 476 of Set 1| comodoro rivadavia
# Processing Record: 477 of Set 1| ust-uda
# Processing Record: 478 of Set 1| chagda
# Datanot found
# Processing Record: 479 of Set 1| hunchun
# Processing Record: 480 of Set 1| chokurdakh
# Processing Record: 481 of Set 1| auki
# Processing Record: 482 of Set 1| cockburn harbour
# Datanot found
# Processing Record: 483 of Set 1| senj
# Processing Record: 484 of Set 1| margate
# Processing Record: 485 of Set 1| kanigoro
# Processing Record: 486 of Set 1| nyurba
# Processing Record: 487 of Set 1| biak
# Processing Record: 488 of Set 1| hayato
# Datanot found
# Processing Record: 489 of Set 1| atar
# Processing Record: 490 of Set 1| alta
# Processing Record: 491 of Set 1| ziro
# Processing Record: 492 of Set 1| zachagansk
# Datanot found
# Processing Record: 493 of Set 1| balkhash
# Processing Record: 494 of Set 1| neuquen
# Processing Record: 495 of Set 1| vao
# Processing Record: 496 of Set 1| tabou
# Processing Record: 497 of Set 1| aksu
# Processing Record: 498 of Set 1| valdemarpils
# Processing Record: 499 of Set 1| kibala
# Processing Record: 500 of Set 1| bandarbeyla
# Processing Record: 501 of Set 1| bafra
# Processing Record: 502 of Set 1| batticaloa
# Processing Record: 503 of Set 1| mana
# Processing Record: 504 of Set 1| ballina
# Processing Record: 505 of Set 1| moyobamba
# Processing Record: 506 of Set 1| wanaka
# Processing Record: 507 of Set 1| patacamaya
# Processing Record: 508 of Set 1| hargeysa
# Processing Record: 509 of Set 1| viking
# Processing Record: 510 of Set 1| verkhoyansk
# Processing Record: 511 of Set 1| santa rosa
# Processing Record: 512 of Set 1| christchurch
# Processing Record: 513 of Set 1| kandi
# Processing Record: 514 of Set 1| nautla
# Processing Record: 515 of Set 1| kpandae
# Processing Record: 516 of Set 1| la sarre
# Processing Record: 517 of Set 1| santiago
# Processing Record: 518 of Set 1| byron bay
# Processing Record: 519 of Set 1| umzimvubu
# Datanot found
# Processing Record: 520 of Set 1| inuvik
# Processing Record: 521 of Set 1| alofi
# Processing Record: 522 of Set 1| newport
# Processing Record: 523 of Set 1| khandwa
# Processing Record: 524 of Set 1| khash
# Processing Record: 525 of Set 1| attawapiskat
# Datanot found
# Processing Record: 526 of Set 1| liaozhong
# Processing Record: 527 of Set 1| acapulco
# Processing Record: 528 of Set 1| bacolod
# Processing Record: 529 of Set 1| podgornoye
# Processing Record: 530 of Set 1| puerto suarez
# Processing Record: 531 of Set 1| miranorte
# Datanot found
# Processing Record: 532 of Set 1| yichang
# Processing Record: 533 of Set 1| russell
# Processing Record: 534 of Set 1| barahona
# Processing Record: 535 of Set 1| bhopal
# Processing Record: 536 of Set 1| thunder bay
# Processing Record: 537 of Set 1| pochutla
# Processing Record: 538 of Set 1| dauphin
# Processing Record: 539 of Set 1| aquiraz
# Processing Record: 540 of Set 1| esmeralda
# Processing Record: 541 of Set 1| grindavik
# Processing Record: 542 of Set 1| narsaq
# Processing Record: 543 of Set 1| rieti
# Processing Record: 544 of Set 1| la paz
# Processing Record: 545 of Set 1| magadan
# Processing Record: 546 of Set 1| karaul
# Datanot found
# Processing Record: 547 of Set 1| waitara
# Processing Record: 548 of Set 1| moree
# Processing Record: 549 of Set 1| bezhanitsy
# Processing Record: 550 of Set 1| vestmannaeyjar
# Processing Record: 551 of Set 1| imbituba
# Processing Record: 552 of Set 1| marystown
# Processing Record: 553 of Set 1| kargala
# Processing Record: 554 of Set 1| south venice
# Processing Record: 555 of Set 1| aripuana
# Processing Record: 556 of Set 1| mersing
# Processing Record: 557 of Set 1| cileunyi
# Processing Record: 558 of Set 1| longlac
# Datanot found
# Processing Record: 559 of Set 1| jimma
# Processing Record: 560 of Set 1| bima
# Processing Record: 561 of Set 1| nishihara
# Processing Record: 562 of Set 1| mount pleasant
# Processing Record: 563 of Set 1| nago
# Processing Record: 564 of Set 1| innisfail
# Processing Record: 565 of Set 1| amambai
# Processing Record: 566 of Set 1| zhenjiang
# Processing Record: 567 of Set 1| dosso
# Processing Record: 568 of Set 1| amderma
# Datanot found
# Processing Record: 569 of Set 1| maldonado
# Processing Record: 570 of Set 1| leshukonskoye
# Processing Record: 571 of Set 1| vila velha
# Processing Record: 572 of Set 1| nisia floresta
# Processing Record: 573 of Set 1| bubaque
# Processing Record: 574 of Set 1| dubbo
# Processing Record: 575 of Set 1| kazachinskoye
# Processing Record: 576 of Set 1| la palma
# Processing Record: 577 of Set 1| xining
# Processing Record: 578 of Set 1| marcona
# Datanot found
# Processing Record: 579 of Set 1| kashi
# Processing Record: 580 of Set 1| souillac
# Processing Record: 581 of Set 1| ruatoria
# Datanot found
# Processing Record: 582 of Set 1| kahului
# Processing Record: 583 of Set 1| svetlogorsk
# Processing Record: 584 of Set 1| kangaatsiaq
# Processing Record: 585 of Set 1| beyneu
# Processing Record: 586 of Set 1| hami
# Processing Record: 587 of Set 1| perpignan
# Processing Record: 588 of Set 1| anloga
# Processing Record: 589 of Set 1| khorixas

# %%
from pprint import pprint

pprint(response.json())
# Out:
# {'base': 'stations',
#  'clouds': {'all': 63},
#  'cod': 200,
#  'coord': {'lat': -20.37, 'lon': 14.97},
#  'dt': 1584557738,
#  'id': 3356213,
#  'main': {'feels_like': 74.55,
#           'grnd_level': 904,
#           'humidity': 52,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 79.2,
#           'temp_max': 79.2,
#           'temp_min': 79.2},
#  'name': 'Khorixas',
#  'sys': {'country': 'NA', 'sunrise': 1584507804, 'sunset': 1584551569},
#  'timezone': 7200,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 238, 'speed': 14.09}}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "Name" : name,
    "Cloudiness (%)" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity (%)" : humidity,
    "Lat" : lat,
    "Long" : long,
    "Max Temp (Fahrenheit)" : max_temp,
    "Wind Speed (mph)" : windspeed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.to_csv("weather_data.csv", encoding="utf-8", index=False)
weather_data.head(30)
# Out:
#                        Name  Cloudiness (%) Country        Date  Humidity (%)  \
# 0   Santa Cruz de la Sierra              75      BO  1584557357            74
# 1           Sfântu Gheorghe              31      RO  1584557652            56
# 2              Richards Bay               0      ZA  1584557420            78
# 3                   Kavieng             100      PG  1584557652            77
# 4                     Tabuk               1      PH  1584557653            83
# 5                   Ushuaia              90      AR  1584557396            81
# 6                  Paracuru              55      BR  1584557653            62
# 7              Punta Arenas              75      CL  1584557522            81
# 8                    Kovdor              99      RU  1584557653            93
# 9                    Marabu              75      MY  1584557653            94
# 10                    Khovd             100      MN  1584557653            51
# 11                Jamestown               1      US  1584557540            52
# 12             Kudahuvadhoo               0      MV  1584557654            76
# 13                   Avarua              75      CK  1584557654            83
# 14              Clyde River              90      CA  1584557654            83
# 15               Quang Ngai              37      VN  1584557654            88
# 16                   Albany               1      US  1584557192            33
# 17             Port Lincoln              77      AU  1584557413            24
# 18                    Dinar              75      TR  1584557655            74
# 19                   Atuona              68      PF  1584557400            79
# 20            Mar del Plata              75      AR  1584557652            88
# 21        São João da Barra              20      BR  1584557655            62
# 22                    Pisco              40      PE  1584557474            30
# 23                 Sobolevo              98      RU  1584557655            77
# 24                  Labuhan             100      ID  1584557656            86
# 25                Tuatapere              38      NZ  1584557656            65
# 26                     Lebu               8      CL  1584557656            47
# 27                   Torbay              90      CA  1584557471            93
# 28             Marsá Maţrūḩ               0      EG  1584557656            61
# 29               Kaitangata             100      NZ  1584557656            77
#
#       Lat    Long  Max Temp (Fahrenheit)  Wind Speed (mph)
# 0  -17.80  -63.17                  84.20             11.41
# 1   45.87   25.78                  43.00              2.19
# 2  -28.78   32.04                  76.44             23.49
# 3   -2.57  150.80                  81.84              5.73
# 4   17.42  121.44                  68.88              5.23
# 5  -54.80  -68.30                  44.60             29.97
# 6   -3.41  -39.03                  87.80             11.41
# 7  -53.15  -70.92                  48.20             18.34
# 8   67.57   30.48                  29.46              6.44
# 9    4.41  114.01                  77.00              2.24
# 10  48.01   91.64                  33.12              7.45
# 11  42.10  -79.24                  52.00             12.75
# 12   2.67   72.89                  84.60             12.06
# 13 -21.21 -159.78                  82.40             16.11
# 14  70.47  -68.59                  -5.80             42.50
# 15  15.12  108.80                  74.46              6.20
# 16  42.60  -73.97                  54.00              6.93
# 17 -34.73  135.87                  82.38             18.25
# 18  38.06   30.17                  35.60             14.99
# 19  -9.80 -139.03                  82.20             14.29
# 20 -38.00  -57.56                  72.00              8.05
# 21 -21.64  -41.05                  86.00             11.41
# 22 -13.70  -76.22                  80.01              9.17
# 23  54.43   31.90                  43.86             13.38
# 24  -6.88  112.21                  75.78              1.99
# 25 -46.13  167.68                  57.99             11.01
# 26 -37.62  -73.65                  69.48              9.44
# 27  47.67  -52.73                  42.01             27.51
# 28  31.35   27.25                  59.88             18.50
# 29 -46.28  169.85                  55.00              1.99

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Latitude vs. Temperature Plot
plt.scatter(lat, max_temp, marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperatures")
plt.ylabel("Temperature (Fahrenheit)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Temperature_Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Latitude vs. Humidity Plot
plt.scatter(lat, humidity, marker="x")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Humidity_Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Latitude vs. Temperature Plot
plt.scatter(lat, cloudiness, marker="*")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness %")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Cloudiness_Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Latitude vs. Wind Speed Plot
plt.scatter(lat, windspeed, marker="d")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (mph)")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Wind_Speed_Plot.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

weather_data_northern = weather_data[(weather_data['Lat'] > 0)]
weather_data_northern_df = pd.DataFrame(weather_data_northern)
weather_data_northern_df
# Out:
#                             Name  Cloudiness (%) Country        Date  \
# 1                Sfântu Gheorghe              31      RO  1584557652
# 4                          Tabuk               1      PH  1584557653
# 8                         Kovdor              99      RU  1584557653
# 9                         Marabu              75      MY  1584557653
# 10                         Khovd             100      MN  1584557653
# ..                           ...             ...     ...         ...
# 536                  Kangaatsiaq              94      GL  1584557737
# 537                       Beyneu              66      KZ  1584557737
# 538                        Kumul              41      CN  1584557737
# 539  Arrondissement de Perpignan               0      FR  1584557738
# 540                       Anloga              20      GH  1584557738
#
#      Humidity (%)    Lat    Long  Max Temp (Fahrenheit)  Wind Speed (mph)
# 1              56  45.87   25.78                  43.00              2.19
# 4              83  17.42  121.44                  68.88              5.23
# 8              93  67.57   30.48                  29.46              6.44
# 9              94   4.41  114.01                  77.00              2.24
# 10             51  48.01   91.64                  33.12              7.45
# ..            ...    ...     ...                    ...               ...
# 536            73  68.31  -53.46                  13.08             20.54
# 537            65  45.32   55.20                  45.18             12.55
# 538            25  42.80   93.45                  48.42              3.33
# 539            62  42.75    2.75                  60.80              2.24
# 540            79   5.79    0.90                  84.20             16.11
#
# [368 rows x 9 columns]

# %%
weather_data_southern = weather_data[(weather_data['Lat'] < 0)]
weather_data_southern_df = pd.DataFrame(weather_data_southern)
weather_data_southern_df
# Out:
#                         Name  Cloudiness (%) Country        Date  \
# 0    Santa Cruz de la Sierra              75      BO  1584557357
# 2               Richards Bay               0      ZA  1584557420
# 3                    Kavieng             100      PG  1584557652
# 5                    Ushuaia              90      AR  1584557396
# 6                   Paracuru              55      BR  1584557653
# ..                       ...             ...     ...         ...
# 525               Vila Velha              40      BR  1584557735
# 526           Nísia Floresta              63      BR  1584557735
# 528                    Dubbo               1      AU  1584557670
# 533                 Souillac              75      MU  1584557737
# 541                 Khorixas              63      NA  1584557738
#
#      Humidity (%)    Lat    Long  Max Temp (Fahrenheit)  Wind Speed (mph)
# 0              74 -17.80  -63.17                  84.20             11.41
# 2              78 -28.78   32.04                  76.44             23.49
# 3              77  -2.57  150.80                  81.84              5.73
# 5              81 -54.80  -68.30                  44.60             29.97
# 6              62  -3.41  -39.03                  87.80             11.41
# ..            ...    ...     ...                    ...               ...
# 525            78 -20.33  -40.29                  84.00             11.41
# 526            62  -6.09  -35.21                  87.80             12.75
# 528            87 -32.25  148.62                  53.60              5.82
# 533            83 -20.52   57.52                  78.80              3.36
# 541            52 -20.37   14.97                  79.20             14.09
#
# [174 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
n_latitude = weather_data_northern_df['Lat']
n_temp = weather_data_northern_df['Max Temp (Fahrenheit)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_latitude, n_temp)
regress_values = n_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(n_latitude,n_temp)

#plot regression line with formula
plt.plot(n_latitude,regress_values,"r-")
plt.annotate(line_eq,(2,2),fontsize=15,color="red")

#Labels and titles
plt.title("Northern City Latitude vs. Maximum Temperature")
plt.xlabel('Latitude')
plt.ylabel('Temperature (Fahrenheit)')
plt.xlim(0,90)
plt.ylim(-30,130)

print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Northern_Latitude_vs_Temperature_Plot.png")
plt.show()
# Out:
# The r-squared is: -0.8852140776445757

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
s_latitude = weather_data_southern_df['Lat']
s_temp = weather_data_southern_df['Max Temp (Fahrenheit)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_latitude, s_temp)
s_regress_values = s_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(s_latitude,s_temp)

#plot regression line with formula
plt.plot(s_latitude,s_regress_values,"r-")
plt.annotate(line_eq,(-80,0),fontsize=15,color="red")

#Labels and titles
plt.title("Southern City Latitude vs. Maximum Temperature")
plt.xlabel('Latitude')
plt.ylabel('Temperature (Fahrenheit)')
plt.xlim(-90,0)
plt.ylim(-30,130)
print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Southern_Latitude_vs_Temperature_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.6474296920493685

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
n_latitude = weather_data_northern_df['Lat']
n_humidity = weather_data_northern_df['Humidity (%)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_latitude, n_humidity)
regress_values = n_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(n_latitude,n_humidity)

#plot regression line with formula
plt.plot(n_latitude,regress_values,"r-")
plt.annotate(line_eq,(50,10),fontsize=15,color="red")

#Labels and titles
plt.title("Northern City Latitude vs. Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.xlim(0,90)
plt.ylim(0,110)

print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Northern_Latitude_vs_Humidity_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.33531841306683857

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
s_latitude = weather_data_southern_df['Lat']
s_humidity = weather_data_southern_df['Humidity (%)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_latitude, s_humidity)
s_regress_values = s_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(s_latitude,s_humidity)

#plot regression line with formula
plt.plot(s_latitude,s_regress_values,"r-")
plt.annotate(line_eq,(-80,20),fontsize=15,color="red")

#Labels and titles
plt.title("Southern City Latitude vs. Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.xlim(-90,0)
plt.ylim(0,110)
print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Southern_Latitude_vs_Humidity_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.19108015118236787

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
n_latitude = weather_data_northern_df['Lat']
n_cloudiness = weather_data_northern_df['Cloudiness (%)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_latitude, n_cloudiness)
regress_values = n_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(n_latitude,n_cloudiness)

#plot regression line with formula
plt.plot(n_latitude,regress_values,"r-")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")

#Labels and titles
plt.title("Northern City Latitude vs. Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.xlim(0,90)
plt.ylim(-30,110)

print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Northern_Latitude_vs_Cloudiness_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.23991094026069731

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
s_latitude = weather_data_southern_df['Lat']
s_cloudiness = weather_data_southern_df['Cloudiness (%)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_latitude, s_cloudiness)
s_regress_values = s_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(s_latitude,s_cloudiness)

#plot regression line with formula
plt.plot(s_latitude,s_regress_values,"r-")
plt.annotate(line_eq,(-80,10),fontsize=15,color="red")

#Labels and titles
plt.title("Southern City Latitude vs. Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.xlim(-90,0)
plt.ylim(-10,110)
print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Southern_Latitude_vs_Cloudiness_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.2335267824248948

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
n_latitude = weather_data_northern_df['Lat']
n_windspeed = weather_data_northern_df['Wind Speed (mph)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_latitude, n_windspeed)
regress_values = n_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(n_latitude,n_windspeed)

#plot regression line with formula
plt.plot(n_latitude,regress_values,"r-")
plt.annotate(line_eq,(10,40),fontsize=15,color="red")

#Labels and titles
plt.title("Northern City Latitude vs. Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.xlim(0,90)
plt.ylim(-10,50)

print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Northern_Latitude_vs_Wind_Speed_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.14554324731851204

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
s_latitude = weather_data_southern_df['Lat']
s_windspeed = weather_data_southern_df['Wind Speed (mph)']

#add regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_latitude, s_windspeed)
s_regress_values = s_latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot data as scatter
plt.scatter(s_latitude,s_windspeed)

#plot regression line with formula
plt.plot(s_latitude,s_regress_values,"r-")
plt.annotate(line_eq,(-40,40),fontsize=15,color="red")

#Labels and titles
plt.title("Southern City Latitude vs. Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.xlim(-90,0)
plt.ylim(-10,50)
print(f"The r-squared is: {rvalue}")

plt.grid(True)

# Save the figure
plt.savefig("Southern_Latitude_vs_Wind_Speed_Plot.png")
plt.show()
# Out:
# The r-squared is: -0.27115191634713876
